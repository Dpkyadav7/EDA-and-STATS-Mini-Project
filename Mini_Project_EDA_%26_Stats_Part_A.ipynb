# %%
#The following data represents the price in dollars for branded shirts in a website NuCLoth

Data= [23,30,20,27,44,26, 35, 20,29,29,25,15,18,27,19,22,12,26,34,15,27,35,26,43,35,14,24,12,23,31,40,35,38,57,22,42,24,21,27,33]
print(Data)
# Out:
# [23, 30, 20, 27, 44, 26, 35, 20, 29, 29, 25, 15, 18, 27, 19, 22, 12, 26, 34, 15, 27, 35, 26, 43, 35, 14, 24, 12, 23, 31, 40, 35, 38, 57, 22, 42, 24, 21, 27, 33]

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from scipy import stats

#Q1. Compute the mean, median and the mode of the data
print("Mean of the data:",np.mean(Data))
print("Median of the data:",np.median(Data))
print("Mode of the data:",stats.mode(Data))
# Out:
# Mean of the data: 27.625
# Median of the data: 26.5
# Mode of the data: ModeResult(mode=array([27]), count=array([4]))

# %%
#Q2. Compute the range , variance and standard deviation of the data
a=max(Data)
b=min(Data)
print("Range of the data:",a-b)
print("Variance of the data:",np.var(Data))
print("Standard Deviation of the data:",np.std(Data))
# Out:
# Range of the data: 45
# Variance of the data: 90.284375
# Standard Deviation of the data: 9.501809038283184

# %%
#Q3.Find the mean deviation for the data 
x_bar=np.mean(Data)
Mean_Deviation = sum([(x - x_bar)  for x in Data]) / len(Data)
print("Mean_Deviation of the data:",Mean_Deviation)
# Out:
# Mean_Deviation of the data: 0.0

# %%
#Q4.Calculate the Pearson coefficient of skewness and comment on the skewness of the data
from scipy.stats import skew
print("Skewness of the data:",skew(Data, axis=0, bias=True))
print("It signifies that the distribution is positively skewed")
# Out:
# Skewness of the data: 0.695211638721276
# It signifies that the distribution is positively skewed

# %%
#Q5. Count the number of data values that fall within two standard deviations of the mean. Compare this with the answer from Chebyshev’s Theorem.
import statistics
std_dev=statistics.stdev(Data)

# %%
#Q6. Find the three quartiles and the interquartile range (IQR).
Q1 = np.percentile(Data, 25)
print("First quartile (Q1):",Q1)

Q2 = np.percentile(Data, 50)
print("Second quartile (Q2):",Q2)

Q3 = np.percentile(Data, 75)
print("Third quartile (Q3):",Q3)

IQR = Q3-Q1
print("Interquartile range:",IQR)
# Out:
# First quartile (Q1): 21.75
# Second quartile (Q2): 26.5
# Third quartile (Q3): 34.25
# Interquartile range: 12.5

# %%
#Q.7 Are there any outliers in the data set ?

low_lim = Q1-1.5 * IQR
up_lim = Q3 + 1.5 * IQR

outlier =[]
for x in Data:
    if ((x> up_lim) or (x<low_lim)):
         outlier.append(x)
print('Outlier in the dataset is:', outlier)
print('Yes Outliers are present in the data set')
# Out:
# Outlier in the dataset is: [57]
# Yes Outliers are present in the data set

# %%
#Q8.Draw a boxplot of the dataset to confirm .
import seaborn as sns
sns.boxplot(Data)
# Out:
# <Axes: >

# %%
#Q9.Find the percentile rank of the datapoint 25.
import pandas as pd

x = np.percentile(Data, 25)
print("25th Percentile of the datapoint 25 is:",x)
# Out:
# 25th Percentile of the datapoint 25 is: 21.75

# %%
#Q10.What is the probability that a shirt cost is above 25 dollar?
Data_df = pd.DataFrame(Data,columns = ['price'])
Data_df.head()
# Out:
#    price
# 0     23
# 1     30
# 2     20
# 3     27
# 4     44

# %%
print('Probability of the shirt cost greater than 25 dollors is:', len(Data_df[Data_df['price']>25])/len(Data))
# Out:
# Probability of the shirt cost greater than 25 dollors is: 0.575

# %%
#Q11.Create a frequency distribution for the data and visualize it appropriately
df = pd.DataFrame(Data)
print("A frequency distribution for the data:\n",df.value_counts())
# Out:
# A frequency distribution for the data:
#  27    4
# 35    4
# 26    3
# 22    2
# 29    2
# 24    2
# 23    2
# 12    2
# 15    2
# 20    2
# 21    1
# 34    1
# 44    1
# 43    1
# 42    1
# 40    1
# 38    1
# 33    1
# 31    1
# 30    1
# 18    1
# 14    1
# 19    1
# 25    1
# 57    1
# dtype: int64

# %%
#"Visualization of frequency table for the data is as follows:

#The value [27,35] occurs "4" times in the Data.
#The value [26] occurs "3" times in the Data.
#The value [23,15,24,12,22,20,29] occurs "2" times in the Data.
#The value [25,21,42,57,38,40,31,14,43,34,44,30,19,18,33] occurs "1" time in the Data.

# %%
#Q12. Create a probability distribution of the data and visualize it appropriately.
import seaborn as sns
import matplotlib.pyplot as plt
 
# plotting a histogram
ax = sns.distplot(Data,
                  bins=40,
                  kde=True,
                  color='blue',
                hist_kws={"linewidth": 20,'alpha':1})
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
plt.show()

# %%
#Visualization of Probability Distribution table for the data is as follows:
#This distribution represents a probability distribution for a data which says data is normally distributed with slight skewness.

# %%
'''Q13.What is the shape of the distribution of this dataset? Create an appropriate graph to determine that. 
Take 100 random samples with replacement from this dataset of size 5 each. Create a sampling distribution of 
the mean shirt prices. Compare with other sampling distributions of sample size 10, 15, 20, 25, 30. 
State your observations. Does it corroborate the Central Limit Theorem?'''
Data= [23,30,20,27,44,26, 35, 20,29,29,25,15,18,27,19,22,12,26,34,15,27,35,26,43,35,14,24,12,23,31,40,35,38,57,22,42,24,21,27,33]

import numpy as np
no_of_sample = 100
sample_size = 5
sample_mean_list=[]
for i in range(no_of_sample):
    sample = np.random.choice(Data,size=sample_size,replace=True) # selecting sample with replacement
    sample_mean = np.mean(sample) # sample mean
    sample_mean_list.append(sample_mean)

# %%
print("Sample Size=5")
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = True,kde = True)
plt.title('Histogram of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = False,kde = True)
plt.title('Density of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Density',fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
# Out:
# Sample Size=5

# %%
no_of_sample = 100
sample_size = 10
sample_mean_list=[]
for i in range(no_of_sample):
    sample = np.random.choice(Data,size=sample_size,replace=True) # selecting sample with replacement
    sample_mean = np.mean(sample) # sample mean
    sample_mean_list.append(sample_mean)

# %%
print("Sample Size=10")
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = True,kde = True)
plt.title('Histogram of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = False,kde = True)
plt.title('Density of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Density',fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.show()
# Out:
# Sample Size=10

# %%
no_of_sample = 100
sample_size = 15
sample_mean_list=[]
for i in range(no_of_sample):
    sample = np.random.choice(Data,size=sample_size,replace=True) # selecting sample with replacement
    sample_mean = np.mean(sample) # sample mean
    sample_mean_list.append(sample_mean)

# %%
print("Sample Size=15")
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = True,kde = True)
plt.title('Histogram of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = False,kde = True)
plt.title('Density of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Density',fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.show()
# Out:
# Sample Size=15

# %%
no_of_sample = 100
sample_size = 20
sample_mean_list=[]
for i in range(no_of_sample):
    sample = np.random.choice(Data,size=sample_size,replace=True) # selecting sample with replacement
    sample_mean = np.mean(sample) # sample mean
    sample_mean_list.append(sample_mean)

# %%
print("Sample Size=20")
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = True,kde = True)
plt.title('Histogram of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = False,kde = True)
plt.title('Density of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Density',fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.show()
# Out:
# Sample Size=20

# %%
no_of_sample = 100
sample_size = 25
sample_mean_list=[]
for i in range(no_of_sample):
    sample = np.random.choice(Data,size=sample_size,replace=True) # selecting sample with replacement
    sample_mean = np.mean(sample) # sample mean
    sample_mean_list.append(sample_mean)

# %%
print("Sample Size=25")
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = True,kde = True)
plt.title('Histogram of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = False,kde = True)
plt.title('Density of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Density',fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.show()
# Out:
# Sample Size=25

# %%
no_of_sample = 100
sample_size = 30
sample_mean_list=[]
for i in range(no_of_sample):
    sample = np.random.choice(Data,size=sample_size,replace=True) # selecting sample with replacement
    sample_mean = np.mean(sample) # sample mean
    sample_mean_list.append(sample_mean)

# %%
print("Sample Size=30")
plt.subplot(1,2,1)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = True,kde = True)
plt.title('Histogram of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.subplot(1,2,2)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
sns.distplot(sample_mean_list,hist = False,kde = True)
plt.title('Density of Sample mean',fontsize=20)
plt.xlabel('Sample mean',fontsize=20)
plt.ylabel('Density',fontsize=20)
plt.subplots_adjust(bottom=0.1, right=2, top=0.9)
plt.show()
# Out:
# Sample Size=30

# %%
'''As We can see that the distribution approaches is not normal as sample size gets larger 
And practically the distribution is normal when sample size is greater than or equal to 30 
So,it does not follow the Central Limit Theorem for given data.'''
# Out:
# 'As We can see that the distribution approaches is not normal as sample size gets larger \nAnd practically the distribution is normal when sample size is greater than or equal to 30 \nSo,it does not follow the Central Limit Theorem for given data.'

# %%
'''Q14. Treat this dataset as a binomial distribution where p is the probability that a shirt costs above 25 dollars.
 What is the probability that out of a random sample of 10 shirts 7 are costing more than 25 dollars'''

prob = 1-stats.binom.sf(k = 7, n = 10, p = 0.575)
prob = round(prob, 2)
print('The probability that out of a random sample of 10 shirts 7 are costing more than 25 dollors is:', prob)
# Out:
# The probability that out of a random sample of 10 shirts 7 are costing more than 25 dollors is: 0.87

# %%
'''Q15. NuCloth Claims that 60% of all shirts in their website cost less than 25 dollars.
Using the Normal approximation of a Binomial distribution,find the probability that in a random sample of 
10 shirts 7 of them will cost less than 25 dollars.'''
prob = stats.binom.cdf(k=7,n=10,p=0.6)
prob=round(prob,2)
print('The probability that in a random sample of 10 shirts 7 of them will cost less than 25 dollars:',prob)
# Out:
# The probability that in a random sample of 10 shirts 7 of them will cost less than 25 dollars: 0.83

# %%
'''Q16. Compute a 95% Confidence Interval for the true price of a shirt in the NuCloth website using appropriate distribution.( State reasons as to why did 
you use a z or t distribution)'''

from scipy.stats import norm

sample_mean = np.mean(Data)
sample_std = np.std(Data)

n = len(Data)
sem = sample_std / np.sqrt(n)


z_crit = norm.ppf(0.975) 
me = z_crit * sem

ci_low = sample_mean - me
ci_high = sample_mean + me


print(f"95% Confidence Interval: ({ci_low:.2f}, {ci_high:.2f})")
# Out:
# 95% Confidence Interval: (24.68, 30.57)

# %% [markdown]
# We use a z-distribution to calculate the margin of error, since we have a large sample size (assumed to be at least 30) and do not know the population standard deviation.

# %%
'''Q17. A data scientist wants to estimate with 95% confidence the true 
proportion of shirts having price greater than 25 dollars in the NuCloth 
website. A recent study showed that 60% of all shirts have a price greater 
than 25 dollars. The data scientist wants to be accurate within 2% of the true 
proportion. Find the minimum sample size necessary.'''

p_hat = 0.6
d = 0.02
z_alpha = norm.ppf(0.975)  


n = ((z_alpha**2) * p_hat * (1 - p_hat)) / (d**2)
n = np.ceil(n)

print(f"The minimum sample size required is {int(n)}")
# Out:
# The minimum sample size required is 2305

# %%
'''Q18. The same data scientist wants to estimate the true proportion of shirts having price greater than 25 dollars. 
She wants to be 90% confident and accurate within 5% of true proportion. Find the minimum sample size necessary'''
p_hat = 0.6
d = 0.05
z_alpha = norm.ppf(0.95)
n = ((z_alpha**2) * p_hat * (1 - p_hat)) / (d**2)
n = np.ceil(n)

print(f"The minimum sample size required is {int(n)}")
# Out:
# The minimum sample size required is 260

# %%
'''Q19. NuCloth claims that currently 80% of all shirts have prices greater than 25 dollars .
Test this claim with an alpha =0.05 if out of a random sample of 30 shirts only 23 are having prices above 25 dollars.'''

# %%
'''Q20. A data scientist is researching the hypothesis that the average price of a shirt in NuCloth is higher than the supermarket. So he collects data from NuCloth and the 
supermarket that the average shirt price of shirts in NuCloth is 36 dollars vs 34 dollars in the supermarket. The standard deviations are 7.6 and 5.8 
respectively.Suppose the data scientist got these values after randomly selecting 100 shirts from each place.
a.What hypothesis would he use to compare the shirt prices of NuCloth vs Supermarket
b.What are critical values to be used?
c.What statistical test will be used to compare these prices?
d.Complete the test and obtain the P-value.
e.Summarize his conclusion based on the P-value.'''

# %% [markdown]
# 20.a)
# Null Hypothesis: The average price of shirts in NuCloth is not significantly higher than the average price of shirts in the Supermarket.
# Alternative Hypothesis: The average price of shirts in NuCloth is significantly higher than the average price of shirts in the Supermarket.

# %%
#20.b) 
from scipy.stats import norm
z_critical = norm.ppf(0.05/2)
print(f"The Critical value to be used is {z_critical}")
# Out:
# The Critical value to be used is -1.9599639845400545

# %% [markdown]
# 20.c) We will use a two-sample z-test to compare the means of the two populations.

# %%
#20.d)
import pandas as pd
from scipy.stats import norm

nucloth = pd.Series([36]*100)
nucloth_std = 7.6

supermarket = pd.Series([34]*100)
supermarket_std = 5.8

test_stat = (nucloth.mean() - supermarket.mean()) / ((nucloth_std**2/100 + supermarket_std**2/100)**0.5)
p_value = 2 * (1 - norm.cdf(abs(test_stat)))

margin_error = 1.96 * ((nucloth_std**2/100 + supermarket_std**2/100)**0.5)
conf_int = (nucloth.mean() - supermarket.mean() - margin_error, nucloth.mean() - supermarket.mean() + margin_error)

print("Test Statistic: ", test_stat)
print("P-value: ", p_value)
print("95% Confidence Interval: ", conf_int)
# Out:
# Test Statistic:  2.09197696327652
# P-value:  0.036440576490224474
# 95% Confidence Interval:  (0.12617439445395573, 3.8738256055460445)

# %% [markdown]
# 20.e The p-value is less than the significance level of 0.05, which suggests that there is strong evidence to reject the null hypothesis. The confidence interval for the difference in means is positive and does not contain zero, indicating that the average price of shirts in NuCloth is significantly higher than the average price of shirts in the Supermarket.
